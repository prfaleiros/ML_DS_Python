# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1,4,6,5,7,10,6])

# %%
s
# Out:
# 0     1
# 1     4
# 2     6
# 3     5
# 4     7
# 5    10
# 6     6
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.mean()
# Out:
# 5.571428571428571

# %%
s.median()
# Out:
# 6.0

# %%
s.max()
# Out:
# 10

# %%
s.min()
# Out:
# 1

# %%
s.std()
# Out:
# 2.760262237369417

# %%
s.sort_values()
# Out:
# 0     1
# 1     4
# 3     5
# 2     6
# 6     6
# 4     7
# 5    10
# dtype: int64

# %%
s.describe()
# Out:
# count     7.000000
# mean      5.571429
# std       2.760262
# min       1.000000
# 25%       4.500000
# 50%       6.000000
# 75%       6.500000
# max      10.000000
# dtype: float64

# %%
df = pd.DataFrame([['fchollet/keras', 11302],['openai/universe',4350],
['pandas-dev/pandas', 8168]])

# %%
df
# Out:
#                    0      1
# 0     fchollet/keras  11302
# 1    openai/universe   4350
# 2  pandas-dev/pandas   8168

# %%
df = pd.DataFrame([['fchollet/keras', 11302],['openai/universe',4350],
['pandas-dev/pandas', 8168]], columns=['repository', 'stars'])

# %%
df
# Out:
#           repository  stars
# 0     fchollet/keras  11302
# 1    openai/universe   4350
# 2  pandas-dev/pandas   8168

# %%
df.columns = ['repo', 'stars']

# %%
df
# Out:
#                 repo  stars
# 0     fchollet/keras  11302
# 1    openai/universe   4350
# 2  pandas-dev/pandas   8168

# %%
df['repo']
# Out:
# 0       fchollet/keras
# 1      openai/universe
# 2    pandas-dev/pandas
# Name: repo, dtype: object

# %%
df.iloc(0)

# %%
df.iloc[0]
# Out:
# repo     fchollet/keras
# stars             11302
# Name: 0, dtype: object

# %%
df.ix[0]
# Out:
# repo     fchollet/keras
# stars             11302
# Name: 0, dtype: object

# %%
import pydataset

# %%
pydataset.data()
# Out:
#                 dataset_id  \
# 0            AirPassengers
# 1                  BJsales
# 2                      BOD
# 3             Formaldehyde
# 4             HairEyeColor
# 5             InsectSprays
# 6           JohnsonJohnson
# 7                LakeHuron
# 8         LifeCycleSavings
# 9                     Nile
# 10           OrchardSprays
# 11             PlantGrowth
# 12               Puromycin
# 13                 Titanic
# 14             ToothGrowth
# 15           UCBAdmissions
# 16          UKDriverDeaths
# 17                   UKgas
# 18             USAccDeaths
# 19               USArrests
# 20          USJudgeRatings
# 21   USPersonalExpenditure
# 22                VADeaths
# 23                WWWusage
# 24             WorldPhones
# 25                airmiles
# 26              airquality
# 27                anscombe
# 28                  attenu
# 29                attitude
# 30                 austres
# 31                    cars
# 32                chickwts
# ...

# %%
titanic = pydataset.data('titanic')

# %%
titanic.head()
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes
# 3  1st class  adults  man      yes
# 4  1st class  adults  man      yes
# 5  1st class  adults  man      yes

# %%
titanic.tail()
# Out:
#           class    age    sex survived
# 1312  3rd class  child  women       no
# 1313  3rd class  child  women       no
# 1314  3rd class  child  women       no
# 1315  3rd class  child  women       no
# 1316  3rd class  child  women       no

# %%
titanic.describe()
# Out:
#             class     age   sex survived
# count        1316    1316  1316     1316
# unique          3       2     2        2
# top     3rd class  adults   man       no
# freq          706    1207   869      817

# %%
from db import DB

# %%
database = DB(filename='C:\\Users\\paulo.faleiros\\AppData\\Local\\Continuum\\Anaconda3\\Lib\\site-packages\\db\\data\\chinook.sqlite', dbtype='sqlite')
# Out:
# Indexing schema. This will take a second...finished!

# %%
database.tables
# Out:
# Refreshing schema. Please wait...done!
# +--------+---------------+----------------------------------------------------------------------------------+
# | Schema | Table         | Columns                                                                          |
# +--------+---------------+----------------------------------------------------------------------------------+
# | public | Album         | AlbumId, Title, ArtistId                                                         |
# | public | Artist        | ArtistId, Name                                                                   |
# | public | Customer      | CustomerId, FirstName, LastName, Company, Address, City, State, Country, PostalC |
# |        |               | ode, Phone, Fax, Email, SupportRepId                                             |
# | public | Employee      | EmployeeId, LastName, FirstName, Title, ReportsTo, BirthDate, HireDate, Address, |
# ...

# %%
album_df = database.tables.Album

# %%
a_df = database.query('select Artist.Name, Album.Title from Album, Artist where Album.ArtistId = Artist.ArtistId')

# %%
a_df
# Out:
#                                                   Name  \
# 0                                                AC/DC
# 1                                               Accept
# 2                                               Accept
# 3                                                AC/DC
# 4                                            Aerosmith
# 5                                    Alanis Morissette
# 6                                      Alice In Chains
# 7                                 Antônio Carlos Jobim
# 8                                         Apocalyptica
# 9                                           Audioslave
# 10                                          Audioslave
# 11                                            BackBeat
# 12                                        Billy Cobham
# 13                                 Black Label Society
# 14                                 Black Label Society
# 15                                       Black Sabbath
# ...

# %%
copacabana = pd.read_csv('..\\data\\copacabana.csv', delimiter = ';')

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# 'C:\\Users\\paulo.faleiros\\OneDrive - Accenture\\1. Digital\\1. MDC\\1. Capability\\Training\\ML_DS_Python\\code'

# %%
copacabana.loc[copacabana['DistPraia'] < 100]
# Out:
#       Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 53          1     1.00   0.01         1248         32         303     1524600
# 62          1     0.01   0.01         1235         38         289     1189386
# 72          1     3.00   0.01         1885         81         799     1447740
# 79          1     1.00   0.01         2307         99         647      986211
# 80          0     1.00   0.01         2307         99         647      986211
# 81          1     0.01   0.01         2307         99         647      986211
# 86          1     4.00   0.01         1582         72         606     1203742
# 151         1     3.00   1.00          601         35         536     1524600
# 163         0     2.00   0.01         3075         52         581     1007098
# 180         1     4.00   1.00         2070         34         770     1524600
# 195         1     3.00   0.01         2631         32         806     1524600
# ...

# %%
titanic.columns
# Out:
# Index(['class', 'age', 'sex', 'survived'], dtype='object')

# %%
titanic['class'].describe()
# Out:
# count          1316
# unique            3
# top       3rd class
# freq            706
# Name: class, dtype: object

# %%
titanic['class'].value_counts()
# Out:
# 3rd class    706
# 1st class    325
# 2nd class    285
# Name: class, dtype: int64

# %%
titanic['class'].nbytes
# Out:
# 1340

# %%
# %%time
titanic['class'] == '3rd class'
# Out:
# Wall time: 501 µs
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
# 30      False
# 31      False
# 32      False
# 33      False
# 34      False
# 35      False
# 36      False
# 37      False
# 38      False
# 39      False
# 40      False
# 41      False
# 42      False
# 43      False
# 44      False
# 45      False
# 46      False
# 47      False
# 48      False
# 49      False
# 50      False
# 51      False
# 52      False
# 53      False
# 54      False
# 55      False
# 56      False
# 57      False
# 58      False
# 59      False
# 60      False
# 61      False
# ...

# %%
# categorize: same as using Factors in R
titanic['class'] = titanic['class'].astype('category')

# %%
df = pd.read_csv('..\\data\\primary-results.csv')

# %%
df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
df.groupby('candidate').aggregate({'votes': [min, np.mean, max]})
# Out:
#                 votes
#                   min         mean     max
# candidate
#  No Preference      0    23.225071     580
#  Uncommitted        0     0.434343      16
# Ben Carson          0   338.258238    9945
# Bernie Sanders      0  2844.019501  434656
# Carly Fiorina       0   139.366972    3612
# Chris Christie      1   223.422018    7144
# Donald Trump        0  3709.576408  179130
# Hillary Clinton     0  3731.855410  590502
# Jeb Bush            2   609.103226    9575
# John Kasich         0  1160.052705  101217
# Marco Rubio         0  1299.834051  111898
# Martin O'Malley     0     7.595960     152
# Mike Huckabee       2    33.787879     565
# Rand Paul           2    85.646465    1633
# Rick Santorum       0    18.000000     234
# Ted Cruz            0  2120.191299  147721

# %%
df[df['votes'] == 590502]
# Out:
#            state state_abbreviation       county    fips     party  \
# 1386  California                 CA  Los Angeles  6037.0  Democrat
#
#             candidate   votes  fraction_votes
# 1386  Hillary Clinton  590502            0.57

# %%
from db import DemoDB

# %%
database = DemoDB()
# Out:
# Indexing schema. This will take a second...finished!

# %%
database.tables
# Out:
# Refreshing schema. Please wait...done!
# +--------+---------------+----------------------------------------------------------------------------------+
# | Schema | Table         | Columns                                                                          |
# +--------+---------------+----------------------------------------------------------------------------------+
# | public | Album         | AlbumId, Title, ArtistId                                                         |
# | public | Artist        | ArtistId, Name                                                                   |
# | public | Customer      | CustomerId, FirstName, LastName, Company, Address, City, State, Country, PostalC |
# |        |               | ode, Phone, Fax, Email, SupportRepId                                             |
# | public | Employee      | EmployeeId, LastName, FirstName, Title, ReportsTo, BirthDate, HireDate, Address, |
# ...

# %%
a_df = database.query('select Artist.Name, Album.Title from Album, Artist where Album.ArtistId = Artist.ArtistId')

# %%
album = database.tables.Album.all()

# %%
album.head()
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %%
artist = database.tables.Artist.all()

# %%
artist.head()
# Out:
#    ArtistId               Name
# 0         1              AC/DC
# 1         2             Accept
# 2         3          Aerosmith
# 3         4  Alanis Morissette
# 4         5    Alice In Chains

# %%
# database.query('select Artist.Name, Album.Title from Album, Artist where Album.ArtistId = Artist.ArtistId')
# do exactly the same. pd.merge searches for same column in both dataframes
album_artist = pd.merge(artist, album)

# %%
album.head()
# Out:
#    AlbumId                                  Title  Artist_Id
# 0        1  For Those About To Rock We Salute You          1
# 1        2                      Balls to the Wall          2
# 2        3                      Restless and Wild          2
# 3        4                      Let There Be Rock          1
# 4        5                               Big Ones          3

# %%
# especifying the column
album_artist = pd.merge(artist, album, on = 'ArtistId')

# %%
album.rename(columns={'ArtistId': 'Artist_Id'}, inplace = True)

# %%
album_artist = pd.merge(artist, album, left_on = 'ArtistId', right_on = 'Artist_Id').drop('Artist_Id', axis = 1)

# %%
album_artist.head()
# Out:
#    ArtistId       Name  AlbumId                                  Title
# 0         1      AC/DC        1  For Those About To Rock We Salute You
# 1         1      AC/DC        4                      Let There Be Rock
# 2         2     Accept        2                      Balls to the Wall
# 3         2     Accept        3                      Restless and Wild
# 4         3  Aerosmith        5                               Big Ones

# %%
database = DB(filename='..\\data\\logs.sqlite3', dbtype='sqlite')
# Out:
# Indexing schema. This will take a second...finished!

# %%
database.tables
# Out:
# Refreshing schema. Please wait...done!
# +--------+-------+-------------------------+
# | Schema | Table | Columns                 |
# +--------+-------+-------------------------+
# | public | log   | id, path, user_id, date |
# +--------+-------+-------------------------+

# %%
log_df = database.tables.log.all()

# %%
log_df.head()
# Out:
#    id                  path  user_id                date
# 0   1                     /        3 2017-01-03 11:41:00
# 1   2              /pandas/        4 2017-01-03 11:37:00
# 2   3              /videos/        5 2017-01-03 10:47:00
# 3   4                     /        2 2017-01-03 11:51:00
# 4   5  /python-para-zumbis/        5 2017-01-03 10:32:00

# %%
log_df.dtypes
# Out:
# id                  int64
# path               object
# user_id             int64
# date       datetime64[ns]
# dtype: object

# %%
log_df['date'] = pd.to_datetime(log_df['date'], format= '%Y-%m-%d %H:%M:%S.%f')

# %%
log_df.set_index(['date'], inplace=True)

# %%
log_df.head()
# Out:
#                      id                  path  user_id
# date
# 2017-01-03 11:41:00   1                     /        3
# 2017-01-03 11:37:00   2              /pandas/        4
# 2017-01-03 10:47:00   3              /videos/        5
# 2017-01-03 11:51:00   4                     /        2
# 2017-01-03 10:32:00   5  /python-para-zumbis/        5

# %%
log_df['2017-01-03 10:47']
# Out:
#                      id      path  user_id
# date
# 2017-01-03 10:47:00   3  /videos/        5
# 2017-01-03 10:47:00  68  /cursos/        5
# 2017-01-03 10:47:00  87  /cursos/        2

# %%
log_df['2017-01-03 10:47':'2017-01-03 10:51']
# Out:
#                      id                path  user_id
# date
# 2017-01-03 10:47:00   3            /videos/        5
# 2017-01-03 10:51:00  32  /django-ecommerce/        2
# 2017-01-03 10:51:00  37                   /        5
# 2017-01-03 10:51:00  46                   /        5
# 2017-01-03 10:48:00  64                   /        3
# 2017-01-03 10:47:00  68            /cursos/        5
# 2017-01-03 10:47:00  87            /cursos/        2
# 2017-01-03 10:49:00  96  /django-ecommerce/        1

# %%
primary_df = pd.read_csv('..\\data\\primary-results.csv')

# %%
primary_df.head()
# Out:
#      state state_abbreviation   county    fips     party        candidate  \
# 0  Alabama                 AL  Autauga  1001.0  Democrat   Bernie Sanders
# 1  Alabama                 AL  Autauga  1001.0  Democrat  Hillary Clinton
# 2  Alabama                 AL  Baldwin  1003.0  Democrat   Bernie Sanders
# 3  Alabama                 AL  Baldwin  1003.0  Democrat  Hillary Clinton
# 4  Alabama                 AL  Barbour  1005.0  Democrat   Bernie Sanders
#
#    votes  fraction_votes
# 0    544           0.182
# 1   2387           0.800
# 2   2694           0.329
# 3   5290           0.647
# 4    222           0.078

# %%
primary_df['candidate'].unique()
# Out:
# array(['Bernie Sanders', 'Hillary Clinton', 'Ben Carson', 'Donald Trump',
#        'John Kasich', 'Marco Rubio', 'Ted Cruz', ' Uncommitted',
#        "Martin O'Malley", 'Carly Fiorina', 'Chris Christie', 'Jeb Bush',
#        'Mike Huckabee', 'Rand Paul', 'Rick Santorum', ' No Preference'], dtype=object)

# %%
pd.pivot_table(primary_df, index=['state', 'party', 'candidate'], values=['votes'], aggfunc={'votes': np.sum})
# Out:
#                                              votes
# state          party      candidate
# Alabama        Democrat   Bernie Sanders     76399
#                           Hillary Clinton   309928
#                Republican Ben Carson         87517
#                           Donald Trump      371735
#                           John Kasich        37970
#                           Marco Rubio       159802
#                           Ted Cruz          180608
# Alaska         Democrat   Bernie Sanders       440
#                           Hillary Clinton       99
#                Republican Ben Carson          2401
#                           Donald Trump        7346
#                           John Kasich          892
#                           Marco Rubio         3318
#                           Ted Cruz            7973
# Arizona        Democrat   Bernie Sanders    163400
#                           Hillary Clinton   235697
#                Republican Donald Trump      249916
# ...

# %%
primary_df['rank'] = primary_df.groupby(['county', 'party'])['votes'].rank(ascending=False)

# %%
primary_df[primary_df['county'] == 'Los Angeles']
# Out:
#            state state_abbreviation       county    fips       party  \
# 1385  California                 CA  Los Angeles  6037.0    Democrat
# 1386  California                 CA  Los Angeles  6037.0    Democrat
# 1519  California                 CA  Los Angeles  6037.0  Republican
# 1520  California                 CA  Los Angeles  6037.0  Republican
# 1521  California                 CA  Los Angeles  6037.0  Republican
#
#             candidate   votes  fraction_votes  rank
# 1385   Bernie Sanders  434656           0.420   2.0
# 1386  Hillary Clinton  590502           0.570   1.0
# 1519     Donald Trump  179130           0.698   1.0
# 1520      John Kasich   33559           0.131   2.0
# 1521         Ted Cruz   30775           0.120   3.0

# %%
primary_df_groupby = primary_df.groupby(['state', 'party', 'candidate']).sum()
del primary_df_groupby['fips']
del primary_df_groupby['fraction_votes']
primary_df_groupby.reset_index(inplace=True)
primary_df_groupby.head(10)
# Out:
#      state       party        candidate   votes    rank
# 0  Alabama    Democrat   Bernie Sanders   76399   555.0
# 1  Alabama    Democrat  Hillary Clinton  309928   266.0
# 2  Alabama  Republican       Ben Carson   87517   966.0
# 3  Alabama  Republican     Donald Trump  371735   390.0
# 4  Alabama  Republican      John Kasich   37970  1340.0
# 5  Alabama  Republican      Marco Rubio  159802   805.5
# 6  Alabama  Republican         Ted Cruz  180608   680.0
# 7   Alaska    Democrat   Bernie Sanders     440    40.0
# 8   Alaska    Democrat  Hillary Clinton      99    80.0
# 9   Alaska  Republican       Ben Carson    2401   150.5

# %%
primary_df_groupby['rank'] = primary_df_groupby.groupby(
['state', 'party'])['votes'].rank(ascending=False)

# %%
primary_df_groupby.head(10)
# Out:
#      state       party        candidate   votes  rank
# 0  Alabama    Democrat   Bernie Sanders   76399   2.0
# 1  Alabama    Democrat  Hillary Clinton  309928   1.0
# 2  Alabama  Republican       Ben Carson   87517   4.0
# 3  Alabama  Republican     Donald Trump  371735   1.0
# 4  Alabama  Republican      John Kasich   37970   5.0
# 5  Alabama  Republican      Marco Rubio  159802   3.0
# 6  Alabama  Republican         Ted Cruz  180608   2.0
# 7   Alaska    Democrat   Bernie Sanders     440   1.0
# 8   Alaska    Democrat  Hillary Clinton      99   2.0
# 9   Alaska  Republican       Ben Carson    2401   4.0

# %%
pd.pivot_table(primary_df_groupby, index=['state', 'party', 'candidate'], values=['rank', 'votes'])
# Out:
#                                            rank    votes
# state          party      candidate
# Alabama        Democrat   Bernie Sanders    2.0    76399
#                           Hillary Clinton   1.0   309928
#                Republican Ben Carson        4.0    87517
#                           Donald Trump      1.0   371735
#                           John Kasich       5.0    37970
#                           Marco Rubio       3.0   159802
#                           Ted Cruz          2.0   180608
# Alaska         Democrat   Bernie Sanders    1.0      440
#                           Hillary Clinton   2.0       99
#                Republican Ben Carson        4.0     2401
#                           Donald Trump      2.0     7346
#                           John Kasich       5.0      892
#                           Marco Rubio       3.0     3318
#                           Ted Cruz          1.0     7973
# Arizona        Democrat   Bernie Sanders    2.0   163400
# ...
